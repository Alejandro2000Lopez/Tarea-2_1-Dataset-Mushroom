# %% [markdown]
# #DataSet Mushroom.

# %% [markdown]
# ##Problematica
# Es poder clasificar el hongo ya sea _comestible_ o _venenoso_ (Clasificación binaria), en función de las características dadas.

# %% [markdown]
# #### Información de las caracteristicas:
# Un hongo se divide en 5 partes principales, cada una de esas partes tiene otras características, ahora, veamos las características del conjunto de datos, para saber si podemos entender ahora o no:
# <br>
# - **clases:** comestible=e, venenoso=p
#
# #### Funciones relacionadas con `Cap`:
# - **forma de gorra:** campana=b, cónica=c, convexa=x, plana=f, nudosa=k, hundida=s
# - **superficie de la tapa:** fibrosa=f, ranuras=g, escamosa=y, lisa=s
# - **color de la tapa:** marrón=n,buff=b,canela=c,gris=g,verde=r,rosa=p,morado=u,rojo=e,blanco=w,amarillo=y
#
# #### Funciones relacionadas con `Gill`:
# - **accesorio branquial:** adjunto=a, descendente=d, libre=f, muesca=n
# - **espaciado branquial:** cerrado=c, abarrotado=w, distante=d
# - **tamaño branquial:** ancho=b, estrecho=n
# - **color de branquias:** negro=k, marrón=n, beige=b, chocolate=h, gris=g, verde=r, naranja=o, rosa=p, morado=u, rojo=e, blanco =w, amarillo=y
#
# #### Funciones relacionadas con `Stalk`:
# - **forma-tallo:** agrandando=e,estrechando=t
#
# - **raíz-tallo:** bulboso=b,club=c,copa=u,igual=e,rizomorfos=z,enraizado=r,faltante=?
#
# - **superficie del tallo sobre el anillo:** fibroso=f,escamoso=y,sedoso=k,liso=s
#
# - **superficie del tallo debajo del anillo:** fibroso=f,escamoso=y,sedoso=k,liso=s
#
# - **color-del-tallo-encima-del-anillo:** marrón=n,buff=b,canela=c,gris=g,naranja=o,rosa=p,rojo=e,blanco=w,amarillo=y
#
# - **color-del-tallo-debajo-del-anillo:** marrón=n,buff=b,canela=c,gris=g,naranja=o,rosa=p,rojo=e,blanco=w,amarillo=y
#
# #### Características relacionadas con `Veil`:
# - **tipo velo:** parcial=p,universal=u
#
# - **color del velo:** marrón=n,naranja=o,blanco=w,amarillo=y
#
# - **número-anillo:** ninguno=n,uno=o,dos=t
#
# - **tipo de anillo:** telaraña=c,evanescente=e,flaring=f,grande=l,ninguno=n,colgante=p,revestimiento=s,zona=z
#
# #### Características `Misc`:
# - **moretones:** moretones=t,no=f
#
# - **olor:** almendra=a, anís=l, creosota=c, pescado=y, asqueroso=f, mohoso=m, ninguno=n, picante=p, especiado=s
#
# - **color de impresión de esporas:** negro=k,marrón=n,buff=b,chocolate=h,verde=r,naranja=o,morado=u,blanco=w,amarillo=y
#
# - **población:** abundante=a,agrupada=c,numerosa=n,dispersa=s,varias=v,solitaria=y
#
# - **hábitat:** pastos=g,hojas=l,prados=m,caminos=p,urbano=u,desechos=w,bosques=d
